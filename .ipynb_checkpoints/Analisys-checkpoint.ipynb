# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import sklearn.cross_validation as CV
from sklearn.feature_extraction import DictVectorizer as DV
from datetime import date
from sklearn import linear_model as LM
import seaborn as sns
import scipy.stats as sts

# %matplotlib inline

# %%
# read data
data = pd.read_csv('train.csv',index_col='Id')

# %%
num_features = data.select_dtypes(exclude=['object']).columns;
obj_features = data.select_dtypes(include=['object']).columns;

# %%
for feature in obj_features:
    plt.figure()
    sns.barplot(x=feature, y="SalePrice", data=data);
# Out:
# /home/frodos/anaconda2/lib/python2.7/site-packages/matplotlib/pyplot.py:516: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)

# %%
data['CentralAir'].describe()
# Out:
# count     1460
# unique       2
# top          Y
# freq      1365
# Name: CentralAir, dtype: object

# %%
for feature in num_features:
    plt.figure()
    sns.barplot(x=feature, y="SalePrice", data=data);

# %%
sns.barplot(x="OverallQual", y="SalePrice", data=data);

# %%
sns.boxplot(x="LotConfig", y="SalePrice", data=data);

# %%
res = np.ndarray([10,2]);
for item in range(1,11):
    res[item-1,0] = item;
    res[item-1,1] = data[data.OverallQual == item].SalePrice.mean()
    
# normalize
plt.figure()
res[:,1] = res[:,1]/res[9,1] 
plt.plot(res[:,0],res[:,1]);

for item, val in res:
    data.loc[data.OverallQual == item,'OverallQualEst'] = val;

plt.figure()
plt.figure(figsize = [10,6])
plt.subplot(121)
sns.regplot(x="OverallQual", y="SalePrice", data=data);
plt.ylim([0, 800000])

plt.subplot(122)
sns.regplot(x="OverallQualEst", y="SalePrice", data=data);
plt.ylim([0, 800000]);

# %%
plt.figure(figsize = [15,10])

plt.subplot(121)
sns.regplot(x="YearBuilt", y="SalePrice", data=data);

plt.subplot(122)
sns.regplot(x="YearRemodAdd", y="SalePrice", data=data);

# %%
data.loc[:,'houseAgeLog'] = np.log1p(date.today().year - data.loc[:,'YearBuilt']);

plt.figure(figsize = [15,10])

plt.subplot(121)
sns.regplot(x="YearBuilt", y="SalePrice", data=data);

plt.subplot(122)
sns.regplot(x="houseAgeLog", y="SalePrice", data=data);

# %%
print 'Build year'
slope, intercept, r_value, p_value, std_err = sts.linregress(data.YearBuilt,data.SalePrice)
print 'R^2', r_value**2

print '  '
print 'Log age'
slope, intercept, r_value, p_value, std_err = sts.linregress(data.houseAgeLog,data.SalePrice)
print 'R^2', r_value**2
# Out:
# Build year
# R^2 0.273421620732
#
# Log age
# R^2 0.339025594279

# %%
empty = pd.isnull(data.GarageYrBlt);
ind = empty[empty == True].index;
data.loc[ind.values,'GarageYrBlt'] = data.loc[ind.values,'YearBuilt'];

data.loc[ind.values,'GarageAgeLog'] = np.log1p(date.today().year - data.GarageYrBlt);

plt.subplot(121)
plt.figure(figsize = [15,10])
sns.regplot(x="GarageYrBlt", y="SalePrice", data=data);
slope, intercept, r_value, p_value, std_err = sts.linregress(data.GarageYrBlt,data.SalePrice)
print 'R^2', r_value**2

plt.subplot(122)
plt.figure(figsize = [15,10])
sns.regplot(x="GarageAgeLog", y="SalePrice", data=data);
slope, intercept, r_value, p_value, std_err = sts.linregress(data.GarageYrBlt,data.SalePrice)
print 'R^2', r_value**2
# Out:
# R^2 0.25810798163
# ---------------------------------------------------------------------------
# LinAlgError                               Traceback (most recent call last)
# <ipython-input-51-c0aa19320cb1> in <module>()
#      13 plt.subplot(122)
#      14 plt.figure(figsize = [15,10])
# ---> 15 sns.regplot(x="GarageAgeLog", y="SalePrice", data=data);
#      16 slope, intercept, r_value, p_value, std_err = sts.linregress(data.GarageYrBlt,data.SalePrice)
#      17 print 'R^2', r_value**2
#
# D:\Anaconda\lib\site-packages\seaborn\linearmodels.pyc in regplot(x, y, data, x_estimator, x_bins, x_ci, scatter, fit_reg, ci, n_boot, units, order, logistic, lowess, robust, logx, x_partial, y_partial, truncate, dropna, x_jitter, y_jitter, label, color, marker, scatter_kws, line_kws, ax)
#     777     scatter_kws["marker"] = marker
#     778     line_kws = {} if line_kws is None else copy.copy(line_kws)
# --> 779     plotter.plot(ax, scatter_kws, line_kws)
#     780     return ax
#     781
#
# D:\Anaconda\lib\site-packages\seaborn\linearmodels.pyc in plot(self, ax, scatter_kws, line_kws)
#     330             self.scatterplot(ax, scatter_kws)
#     331         if self.fit_reg:
# --> 332             self.lineplot(ax, line_kws)
#     333
#     334         # Label the axes
#
# D:\Anaconda\lib\site-packages\seaborn\linearmodels.pyc in lineplot(self, ax, kws)
#     375
#     376         # Fit the regression model
# --> 377         grid, yhat, err_bands = self.fit_regression(ax)
#     378
#     379         # Get set default aesthetics
#
# D:\Anaconda\lib\site-packages\seaborn\linearmodels.pyc in fit_regression(self, ax, x_range, grid)
#     207             yhat, yhat_boots = self.fit_logx(grid)
#     208         else:
# --> 209             yhat, yhat_boots = self.fit_fast(grid)
#     210
#     211         # Compute the confidence interval at each grid point
#
# D:\Anaconda\lib\site-packages\seaborn\linearmodels.pyc in fit_fast(self, grid)
#     222         grid = np.c_[np.ones(len(grid)), grid]
#     223         reg_func = lambda _x, _y: np.linalg.pinv(_x).dot(_y)
# --> 224         yhat = grid.dot(reg_func(X, y))
#     225         if self.ci is None:
#     226             return yhat, None
#
# D:\Anaconda\lib\site-packages\seaborn\linearmodels.pyc in <lambda>(_x, _y)
#     221         X, y = np.c_[np.ones(len(self.x)), self.x], self.y
#     222         grid = np.c_[np.ones(len(grid)), grid]
# --> 223         reg_func = lambda _x, _y: np.linalg.pinv(_x).dot(_y)
#     224         yhat = grid.dot(reg_func(X, y))
#     225         if self.ci is None:
#
# D:\Anaconda\lib\site-packages\numpy\linalg\linalg.pyc in pinv(a, rcond)
#    1613     """
#    1614     a, wrap = _makearray(a)
# -> 1615     _assertNoEmpty2d(a)
#    1616     a = a.conjugate()
#    1617     u, s, vt = svd(a, 0)
#
# D:\Anaconda\lib\site-packages\numpy\linalg\linalg.pyc in _assertNoEmpty2d(*arrays)
#     220     for a in arrays:
#     221         if a.size == 0 and product(a.shape[-2:]) == 0:
# --> 222             raise LinAlgError("Arrays cannot be empty")
#     223
#     224
#
# LinAlgError: Arrays cannot be empty
