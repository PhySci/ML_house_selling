# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import sklearn.cross_validation as CV
from sklearn.feature_extraction import DictVectorizer as DV
from datetime import date
from sklearn import linear_model as LM
import seaborn as sns
# %matplotlib inline

# %%
# read data
data = pd.read_csv('train.csv',index_col='Id')

# %%
num_features = data.select_dtypes(exclude=['object']).columns;
obj_features = data.select_dtypes(include=['object']).columns;

# %%
for feature in obj_features:
    plt.figure()
    sns.barplot(x=feature, y="SalePrice", data=data);
# Out:
# D:\Anaconda\lib\site-packages\matplotlib\pyplot.py:516: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)

# %%
data['CentralAir'].describe()
# Out:
# count     1460
# unique       2
# top          Y
# freq      1365
# Name: CentralAir, dtype: object

# %%
for feature in num_features:
    plt.figure()
    sns.barplot(x=feature, y="SalePrice", data=data);
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-21-5be1f3f2161b> in <module>()
#       1 for feature in num_features:
#       2     plt.figure()
# ----> 3     sns.barplot(x=feature, y="SalePrice", data=data);
#       4     plt.xlabel(feature)
#
# D:\Anaconda\lib\site-packages\seaborn\categorical.pyc in barplot(x, y, hue, data, order, hue_order, estimator, ci, n_boot, units, orient, color, palette, saturation, errcolor, errwidth, capsize, ax, **kwargs)
#    2897                           estimator, ci, n_boot, units,
#    2898                           orient, color, palette, saturation,
# -> 2899                           errcolor, errwidth, capsize)
#    2900
#    2901     if ax is None:
#
# D:\Anaconda\lib\site-packages\seaborn\categorical.pyc in __init__(self, x, y, hue, data, order, hue_order, estimator, ci, n_boot, units, orient, color, palette, saturation, errcolor, errwidth, capsize)
#    1543                                  order, hue_order, units)
#    1544         self.establish_colors(color, palette, saturation)
# -> 1545         self.estimate_statistic(estimator, ci, n_boot)
#    1546
#    1547         self.errcolor = errcolor
#
# D:\Anaconda\lib\site-packages\seaborn\categorical.pyc in estimate_statistic(self, estimator, ci, n_boot)
#    1449                     boots = bootstrap(stat_data, func=estimator,
#    1450                                       n_boot=n_boot,
# -> 1451                                       units=unit_data)
#    1452                     confint.append(utils.ci(boots, ci))
#    1453
#
# D:\Anaconda\lib\site-packages\seaborn\algorithms.pyc in bootstrap(*args, **kwargs)
#      74         resampler = rs.randint(0, n, n)
#      75         sample = [a.take(resampler, axis=0) for a in args]
# ---> 76         boot_dist.append(func(*sample, **func_kwargs))
#      77     return np.array(boot_dist)
#      78
#
# D:\Anaconda\lib\site-packages\numpy\core\fromnumeric.pyc in mean(a, axis, dtype, out, keepdims)
#    2876
#    2877     return _methods._mean(a, axis=axis, dtype=dtype,
# -> 2878                           out=out, keepdims=keepdims)
#    2879
#    2880
#
# D:\Anaconda\lib\site-packages\numpy\core\_methods.pyc in _mean(a, axis, dtype, out, keepdims)
#      61     # Cast bool, unsigned int, and int to float64 by default
#      62     if dtype is None and issubclass(arr.dtype.type, (nt.integer, nt.bool_)):
# ---> 63         dtype = mu.dtype('f8')
#      64
#      65     ret = umr_sum(arr, axis, dtype, out, keepdims)
#
# KeyboardInterrupt:

# %%
for feature in num_features:
    plt.figure()
    plt.scatter(data[feature], data['SalePrice']);

# %%
sns.barplot(x="OverallQual", y="SalePrice", data=data);

# %%
sns.barplot(x="LotConfig", y="SalePrice", data=data);

# %%
plt.figure(figsize = [10,10])
plt.subplot(211)
sns.residplot(x="OverallQual", y="SalePrice", data=data); 
plt.subplot(212)
sns.regplot(x="OverallQual", y="SalePrice", data=data);

# %%
data["OverallQualLog"]=np.log(data["OverallQual"]*10)
plt.figure(figsize = [10,10])
plt.subplot(211)
sns.residplot(x="OverallQualLog", y="SalePrice", data=data);
plt.subplot(212)
sns.regplot(x="OverallQualLog", y="SalePrice", data=data);

# %%
data["OverallQualSqrt"]=np.power(data["OverallQual"],0.3)
sns.residplot(x="OverallQualSqrt", y="SalePrice", data=data); 
sns.lmplot(x="OverallQualSqrt", y="SalePrice", data=data);
