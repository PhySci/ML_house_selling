# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import sklearn.cross_validation as CV
from sklearn.ensemble import GradientBoostingRegressor as GBR
from sklearn.feature_extraction import DictVectorizer as DV
from datetime import date

# %matplotlib inline

# %%
data = pd.read_csv('train.csv',index_col='Id')
features = data.drop('SalePrice',axis = 1)
price = data.SalePrice
plt.hist(price,bins = 100)
plt.xlabel('Price')
plt.ylabel('Counts')
plt.title('Price distribution')
plt.show()

# %% [markdown]
# ## Search empty numeric values

# %%
num_columns = features.select_dtypes(exclude=['object']).columns
obj_columns = features.select_dtypes(include=['object']).columns

for feature in num_columns:
    empty = pd.isnull(features[feature]);
    count = empty[empty == True].count()
    if count>0:
        print feature, count, count*100.0/1460
        

obj_features = features[obj_columns];
obj_features.fillna('empty',inplace=True);

encoder = DV(sparse = False);
t = obj_features.T.to_dict().values();
encoded_data = encoder.fit_transform(t);
# Out:
# LotFrontage 259 17.7397260274
# MasVnrArea 8 0.547945205479
# GarageYrBlt 81 5.54794520548
# D:\Anaconda\lib\site-packages\pandas\core\frame.py:2756: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   downcast=downcast, **kwargs)

# %% [markdown]
# ## Define score function

# %%
def myScore(y, y_pred):
    yLog = np.log10(y);
    ind = np.isinf(yLog);
    yLog[ind == True] = 0;    
    
    y_predLog = np.log10(y_pred);
    ind = np.isinf(y_predLog);
    y_predLog[ind == True] = 0;
    
    summ = np.sum(np.power(yLog-y_predLog,2))     
    return np.sqrt(summ/y.shape[0])

# %% [markdown]
# ## Test GB Regression for raw numerical data

# %% [markdown]
# ## Create folds and trees

# %%
folds = CV.KFold(price.size, n_folds=5, random_state = 43);
shuffle = CV.ShuffleSplit(price.size, n_iter=3, test_size=0.33, random_state=43)
trees = GBR(verbose = 0, n_estimators = 500, max_depth = 4);
trees.loss_ = myScore

# %% [markdown]
# ## Raw data

# %%
# Raw data
num_features1 = features[num_columns];
num_features1.fillna(0,inplace=True);
transFeatures1 = np.hstack([num_features1, encoded_data]);

CVS = CV.cross_val_score(trees, transFeatures1, price, cv=folds,n_jobs = 8);
print CVS
print CVS.mean()
# Out:
# [ 0.9075033   0.83232534  0.90877006  0.91284266  0.90197878]
# 0.892684028657

# %% [markdown]
# ## Fill garage year

# %%
num_features2 = features[num_columns];
# process GarageYrBlt
empty = pd.isnull(num_features2['GarageYrBlt']);
ind = empty[empty == True].index;
num_features2.loc[ind.values,'GarageYrBlt'] = num_features2.loc[ind.values,'YearBuilt'];
# Out:
# D:\Anaconda\lib\site-packages\pandas\core\indexing.py:461: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s

# %%
num_features2.fillna(0,inplace=True);
transFeatures2 = np.hstack([num_features2, encoded_data]);

CVS2 = CV.cross_val_score(trees, transFeatures2, price, cv=folds,n_jobs = 8);
print CVS2
print CVS2.mean()
# Out:
# [ 0.90745905  0.85137076  0.90850826  0.90232671  0.90362252]
# 0.894657461835

# %% [markdown]
# ## Add spline for lot age

# %%
num_features3 = features[num_columns];
# add new feature
num_features3['houseAgeLog'] = np.log(date.today().year - num_features3.loc[:,'YearBuilt']);
num_features3.fillna(0,inplace=True);
transFeatures3 = np.hstack([num_features3, encoded_data]);
plt.scatter(num_features3['houseAgeLog'],price);
# Out:
# D:\Anaconda\lib\site-packages\ipykernel\__main__.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   app.launch_new_instance()

# %%
CVS3 = CV.cross_val_score(trees, transFeatures3, price, cv=folds,n_jobs = 8);
print CVS3
print CVS3.mean()
# Out:
# [ 0.90895251  0.84912302  0.90857609  0.9070704   0.89780435]
# 0.894305272481

# %% [markdown]
# ## Fill garage age and spline for lot age

# %%
num_features4 = features[num_columns];

# add new feature
num_features4['houseAgeLog'] = np.log(date.today().year - num_features4.loc[:,'YearBuilt']);

# process GarageYrBlt
empty = pd.isnull(num_features4['GarageYrBlt']);
ind = empty[empty == True].index;
num_features4.loc[ind.values,'GarageYrBlt'] = num_features4.loc[ind.values,'YearBuilt'];

num_features4.fillna(0,inplace=True);
transFeatures4 = np.hstack([num_features4, encoded_data]);
# Out:
# D:\Anaconda\lib\site-packages\ipykernel\__main__.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
CVS4 = CV.cross_val_score(trees, transFeatures4, price, cv=folds,n_jobs = 8);
print CVS4
print CVS4.mean()
# Out:
# [ 0.90776118  0.84765413  0.91205198  0.90283778  0.90949691]
# 0.895960394568

# %% [markdown]
# ## Fill garage age and splines for all time series

# %%
num_features5 = features[num_columns];

# process GarageYrBlt
empty = pd.isnull(num_features5['GarageYrBlt']);
ind = empty[empty == True].index;
num_features5.loc[ind.values,'GarageYrBlt'] = features.loc[ind.values,'YearBuilt'];


# add new feature
num_features5.loc[:,'houseAgeLog'] = np.log(date.today().year - num_features5.loc[:,'YearBuilt']);
num_features5.loc[:,'garageAgeLog'] = np.log(date.today().year - num_features5.loc[:,'GarageYrBlt']);
num_features5.loc[:,'remodeAge'] = np.log(date.today().year - num_features5.loc[:,'YearBuilt']); #num_features5.loc[:,'YearRemodAdd']);
num_features5.loc[:,'remodeAgeLog'] = np.log(date.today().year - num_features5.loc[:,'YearBuilt']); #num_features5.loc[:,'YearRemodAdd']);

num_features5.fillna(0,inplace=True);
transFeatures5 = np.hstack([num_features5, encoded_data]);

CVS5 = CV.cross_val_score(trees, transFeatures5, price, cv=folds,n_jobs = 8);
print CVS5
print CVS5.mean()
# Out:
# [ 0.89602451  0.83763309  0.90291688  0.91448298  0.87922434]
# 0.886056358861

# %%
np.log(0)
# Out:
# -inf

# %% [markdown]
# ## Drop date of sold

# %%
num_features6 = num_features5.copy()
num_features6.drop(['MoSold', 'YrSold'],axis = 1);
transFeatures6 = np.hstack([num_features6, encoded_data]);

CVS6 = CV.cross_val_score(trees, transFeatures6, price, cv=folds,n_jobs = 8);
print CVS6
print CVS6.mean()
# Out:
# [ 0.89712098  0.84712883  0.89979697  0.91542966  0.88567284]
# 0.889029859012

# %%
print CVS.mean()
print CVS2.mean()
print CVS3.mean()
print CVS4.mean()
print CVS5.mean()
# Out:
# 0.892684028657
# 0.894657461835
# 0.894305272481
# 0.894365191133
# 0.895159467581

# %% [markdown]
# ## Analize date of sold

# %%
plt.figure();
plt.subplot(131);
plt.scatter(num_features3['YrSold'],price);
plt.title('Year of sold');
plt.subplot(132);
num_features3['YrSold'].hist();
plt.title('Year of sold');
plt.subplot(133);


plt.figure();
plt.subplot(121);
plt.scatter(num_features3['YrSold'],price);
plt.subplot(122);
num_features3['MoSold'].hist();
plt.title('Year of sold');

# %% [markdown]
# Похоже, что дата продажи абсолютно не влияет на цену. Попробую исключить эти признаки и обучить модель.

# %% [markdown]
# ## Try to find correlated features

# %%
features[num_columns].corr()
# Out:
#                MSSubClass  LotFrontage   LotArea  OverallQual  OverallCond  \
# MSSubClass       1.000000    -0.386347 -0.139781     0.032628    -0.059316
# LotFrontage     -0.386347     1.000000  0.426095     0.251646    -0.059213
# LotArea         -0.139781     0.426095  1.000000     0.105806    -0.005636
# OverallQual      0.032628     0.251646  0.105806     1.000000    -0.091932
# OverallCond     -0.059316    -0.059213 -0.005636    -0.091932     1.000000
# YearBuilt        0.027850     0.123349  0.014228     0.572323    -0.375983
# YearRemodAdd     0.040581     0.088866  0.013788     0.550684     0.073741
# MasVnrArea       0.022936     0.193458  0.104160     0.411876    -0.128101
# BsmtFinSF1      -0.069836     0.233633  0.214103     0.239666    -0.046231
# BsmtFinSF2      -0.065649     0.049900  0.111170    -0.059119     0.040229
# BsmtUnfSF       -0.140759     0.132644 -0.002618     0.308159    -0.136841
# ...
